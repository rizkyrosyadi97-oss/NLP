# %%
sentence = "Her cat's name is Luna"

# %%
lower_sentence = sentence.lower()

# %%
print(lower_sentence)
# Out:
# her cat's name is luna

# %%
sentence_list = ["Maya pergi ke pasar",
                 "Intan adalah saudara Perempuan Aldy",
                 "Pada hari Minggu saya pergi memancing"]

# %%
sentence_list_lower = [i.lower() for i in sentence_list]
print(sentence_list_lower)
# Out:
# ['maya pergi ke pasar', 'intan adalah saudara perempuan aldy', 'pada hari minggu saya pergi memancing']
