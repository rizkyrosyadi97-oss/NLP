# %% [markdown]
# ## Belajar tentang Regex

# %% [markdown]
# regex adalah sebuah tools yang digunakan untuk membuat sebuah pola yang biasanya digunakan untuk menghapus hal yang tidak perlu disebuah data sesuai pola yang diatur

# %%
import re

# %%
my_folder = "C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop
# otes
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/k9/_2yq1h015519rfxrs8qwcs0c0000gn/T/ipykernel_2509/4072164317.py:1: SyntaxWarning: invalid escape sequence '\d'
#   my_folder = "C:\desktop\notes"
